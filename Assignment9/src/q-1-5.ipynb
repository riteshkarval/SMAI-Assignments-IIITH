# %%
import pandas as pd

# %% [markdown]
# # Q-1-2

# %% [raw]
# stats on Linear decoder output data

# %%
d = pd.DataFrame([0.7108468261928643,0.4608596831338993,0.9886759832877107,0.8763074124602092,0.8232041812448706])
ax = d.plot.bar()

# %% [raw]
# stats on non-Linear decoder output data

# %%
d = pd.DataFrame([0.6382151453434549,0.4818802122820318,0.9867924008051396,0.8017440282301845,0.9298270186987885])
ax = d.plot.bar()

# %% [markdown]
# # Q-1-3

# %%
d = pd.DataFrame([0.37682299347818965,1.0,0.8592653735039207,0.9168656812754147,1.0])
ax = d.plot.bar()

# %% [markdown]
# # Q-1-4

# %% [raw]
# stats on Linear decoder output data

# %%
d = pd.DataFrame([1.0,0.5354567307692307,1.0,0.5,1.0])
ax = d.plot.bar()

# %% [raw]
# stats on non-Linear decoder output data

# %%
d = pd.DataFrame([0.5345370879807932,1.0,1.0,1.0,1.0])
ax = d.plot.bar()
